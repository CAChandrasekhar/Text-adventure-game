# %%
"""
# Aayirathil Oruvan - Game:
    
This is a treasure hunt game. This game is based on an Indian movie ". In 1279 A.D., 
the downfall of the Chola This is a treasure hunt game. This game is based on an Indian movie ". 
This movie is based on the downfall of the Chola dynasty seems imminent as the Pandyas drive 
the Chola people out of their kingdom in southern India. 
The Chola's take along with a sacred idol and treasure from Pandyas and store it in a secret place. 
To capture the escaped Cholas and the stolen idol, the Pandyas went to all unexplored territories 
but they could not find them. At last, they found the secret place. Your enemies have set up 5 traps. 
You have to face 4 traps set by enemies and capture the sacred idol and treasure.

# Reference page:
https://en.wikipedia.org/wiki/Aayirathil_Oruvan_(2010_film)"""

# importing required functions
import time
import sys
import socket
import random

# creating a list of questions to run the game
list_of_questions = ["What goes up and down but doesn’t move?",
                     "I’m tall when I’m young, but short when I’m old.",
                     "During what month do people sleep the least?",
                     "What disappears as soon as you say its name?",
                     "I am full of holes but can still hold water, what am I?",
                     "Only one color, but not one size, Stuck at the bottom, yet easily flies, Present in sun, but not in rain, Doing no harm, and feeling no pain. What is it?",
                     "What kind of nut has no shell?",
                     "I repeat only the last word your say. The more I repeat, the softer I got. I cannot be seen but can be heard. What am I?",
                     "What can travel the world while staying in the corner?",
                     "What is the difference between yesterday and tomorrow?",
                     "What has hands but cannot clap?"]

# creating a list of opitons to the questions
list_of_answers = [["Water", "Road", "Clouds", "Wind"],
                   ["Candle", "Building", "Tree", "Plant"],
                   ["March", "December", "February", "April"],
                   ["Help", "Wait", "The cat", "Silence"],
                   ["Sponge", "Pot", "Bathtub", "Glass"],
                   ["Cat", "Shadow", "Moon", "Sun"],
                   ["Peach", "Brain", "Doughnut", "Mango"],
                   ["Loud voices", "Echo", "Song", "Music"],
                   ["Stamp", "Globe", "Airplane", "Albatross"],
                   ["Unknown", "Time", "Today", "Shadow"],
                   ["House", "Picther", "Dog", "Clock"]]

# creating a list of answers to the questions
list_correct_answers = ["Road",
                        "Candle",
                        "February",
                        "Silence",
                        "Sponge",
                        "Shadow",
                        "Doughnut",
                        "Echo",
                        "Stamp",
                        "Today",
                        "Clock"]


# Welcome note
def intro():
    print("Welcome to treasure Aayirathil Oruvan game.")

# asking user name
    print("What's your name?")

    user_name = input(prompt="").capitalize()

# dynamically applying user input
    print(f"welcome {user_name}!")

# printing the game introduction
    print("Enemies have captured your sacred idol and stored it in a secret place.")

    time.sleep(1)
    print("You have to capture the Idol and treasure captured by the enemies")
    time.sleep(1)

    print(f"""\nYou have to face 4 traps set by the enemies and capture the Idol and treaure.""")
    time.sleep(1)

# applying while loop for starting the game
    Input = False
    while Input == False:
        answer = input(prompt="Are you certain to find the treasure? yes or no?")

# developing the conditional statement to start the game
        if answer == "yes":
            print("lets's begin the game!")
            print("You have only 2 opportunities for each stage")
            
            start()

        elif answer == "no":
            print("You dont have guts to play this game")
            sys.exit(0)
            
        else:
            print("Invalid entry. Please try again.\n")


# defining start
def start():

    print(f"""\nTrap 1 - Snakes""")
    time.sleep(1)

    print(f"""\nYou reach to a particular place in the forest, you are in a tent.
You being an archaeologist, predicts that they may be attacked by snakes
since it is one of the traps set by Cholas.""")
    time.sleep(3)

    print(f"""\nIf you solve the below puzzle, you will get divine powers and you can cross the sand desert just in a second.""")
    time.sleep(2)

# printing the random question from list of questions
    question = random.choice(list_of_questions)

    print(question)

# returning the index of the element of the list
    index = list_of_questions.index(question)

# search for the element with the same index on the answers list
    answer = list_of_answers[index]

    correct_answer_lower = list_correct_answers[index].lower()

    correct_answer_upper = list_correct_answers[index]

# popping the element out of the list
    list_of_questions.pop(index)
    list_of_answers.pop(index)
    list_correct_answers.pop(index)

    counter = 0

    print("please answer the question!")
    input_user = input(prompt="\n"
                              ">>")

    if input_user == correct_answer_upper or input_user == correct_answer_lower:
        print(f"""\nHurray! You crossed the Trap - 1""")
        print('*' * 100)

    elif input_user != correct_answer_upper or input_user != correct_answer_lower:

        print("mmmm...that is not quite correct\n"
              "here is a list, one of these should be correct", answer)

    second_input = input(prompt="please answer\n"
                                ">>")

    if second_input == correct_answer_upper or second_input == correct_answer_lower:
        print(f"""\nHurray! You crossed the Trap - 1""")
        print('*' * 100)

        sea_creature()

    elif second_input != correct_answer_upper or second_input != correct_answer_lower:

        game_over("Oops! Monster killed you")
        print("Thanks for playing!")
        quit()


# defining Trap 2 - sea_creature
def sea_creature():

    print(f"""\nTrap 2 - Sea creature""")
    time.sleep(1)

    print(f"""\nThey resemble orange glowing lotus leaves which emerge\n
out from the sea and gets stuck to the human body.\n
The boat cannot proceed further till the shore of the island\n
you must walk a few distances in the water which is still below knee level.\n""")

    time.sleep(3)

# printing the random question from list of questions
    question = random.choice(list_of_questions)
    print(question)

# returning the index of the element of the list
    index = list_of_questions.index(question)

# search for the element with the same index on the answers list
    answer = list_of_answers[index]

    correct_answer_lower = list_correct_answers[index].lower()

    correct_answer_upper = list_correct_answers[index]

# popping the element out of the list
    list_of_questions.pop(index)
    list_of_answers.pop(index)
    list_correct_answers.pop(index)

    counter = 0

    print("please answer the question!")
    input_user = input(prompt="\n"
                              ">>")

    if input_user == correct_answer_upper or input_user == correct_answer_lower:
        print(f"""\nHurray! You crossed the Trap - 2""")
        print('*' * 100)

    elif input_user != correct_answer_upper or input_user != correct_answer_lower:

        print("mmmm...that is not quite correct\n"
              "here is a list, one of these should be correct", answer)

    second_input = input(prompt="please answer\n"
                                ">>")

    if second_input == correct_answer_upper or second_input == correct_answer_lower:
        print(f"""\nHurray! You crossed the Trap - 2""")
        print('*' * 100)

        cannibals()

    elif second_input != correct_answer_upper or second_input != correct_answer_lower:

        game_over("Oops! Monster killed you")
        print("Thanks for playing!")
        
        quit()


# defining Trap 3 - cannibals
def cannibals():
    print(f"""\nTrap 3 - Cannibals""")
    time.sleep(1)

# some prompts
    print(f"""\nThese people are encountered by you, once you walk into in the island.""")

    print(f"""One can avoid death by not looking into their faces directly.""")
    time.sleep(3)

# printing the random question from list of questions
    question = random.choice(list_of_questions)
    print(question)

# returning the index of the element of the list
    index = list_of_questions.index(question)

# search for the element with the same index on the answers list
    answer = list_of_answers[index]

    correct_answer_lower = list_correct_answers[index].lower()

    correct_answer_upper = list_correct_answers[index]

# popping the element out of the list
    list_of_questions.pop(index)
    list_of_answers.pop(index)
    list_correct_answers.pop(index)

    counter = 0

    print("please answer the question!")
    input_user = input(prompt="\n"
                              ">>")

    if input_user == correct_answer_upper or input_user == correct_answer_lower:

        print(f"""\nHurray! You crossed the Trap - 3""")
        print('*' * 100)

    elif input_user != correct_answer_upper or input_user != correct_answer_lower:

        print("mmmm...that is not quite correct\n"
              "here is a list, one of these should be correct", answer)
        time.sleep(1)

    second_input = input(prompt="please answer\n"
                                ">>")
    if second_input == correct_answer_upper or second_input == correct_answer_lower:
        print(f"""\nHurray! You crossed the Trap - 3""")
        print('*' * 100)

        quick_sand()

    elif second_input != correct_answer_upper or second_input != correct_answer_lower:

# the player is dead, call game_over() function with the "reason"
        game_over("Oops! Monster killed you")
        print("Thanks for playing!")
        quit()


# defining trap 4 - quick_sand
def quick_sand():

    print(f"""\nTrap 4 - Quick sand""")
    time.sleep(1)

# some prompts
    print(f"""\n
Stepping on a particular area may lead to the formation of a deep pit which will fill automatically due to the quicksand presence.
So if you walk on the sand, in a random place, the ground under your feet will break and you will fall into the pit and the sand will seal the pit automatically.\n""")
    time.sleep(3)

# printing the random question from list of questions
    question = random.choice(list_of_questions)
    print(question)

# returning the index of the element of the list
    index = list_of_questions.index(question)

# search for the element with the same index on the answers list
    answer = list_of_answers[index]

    correct_answer_lower = list_correct_answers[index].lower()

    correct_answer_upper = list_correct_answers[index]

# popping the element out of the list
    list_of_questions.pop(index)
    list_of_answers.pop(index)
    list_correct_answers.pop(index)

    counter = 0

    print("please answer the question!")
    input_user = input(prompt="\n"
                              ">>")

    if input_user == correct_answer_upper or input_user == correct_answer_lower:
        print(f"""\n   
   _____                            _         _       _   _                 _ 
  / ____|                          | |       | |     | | (_)               | |
 | |     ___  _ __   __ _ _ __ __ _| |_ _   _| | __ _| |_ _  ___  _ __  ___| |
 | |    / _ \| '_ \ / _` | '__/ _` | __| | | | |/ _` | __| |/ _ \| '_ \/ __| |
 | |___| (_) | | | | (_| | | | (_| | |_| |_| | | (_| | |_| | (_) | | | \__ \_|
  \_____\___/|_| |_|\__, |_|  \__,_|\__|\__,_|_|\__,_|\__|_|\___/|_| |_|___(_)
                     __/ |                                                    
                    |___/                                                     
        
        """)

        print(f"""\nYou fought bravely and restored the sacred idol and treasure.""")
        sys.exit(0)

    elif input_user != correct_answer_upper or input_user != correct_answer_lower:

        print("mmmm... that is not quite correct\n"
              "here is a list, one of these should be correct", answer)
        time.sleep(1)

    second_input = input(prompt="please answer\n"
                                ">>")

    if second_input == correct_answer_upper or second_input == correct_answer_lower:

        print(f"""\n  
        
         
   _____                            _         _       _   _                 _ 
  / ____|                          | |       | |     | | (_)               | |
 | |     ___  _ __   __ _ _ __ __ _| |_ _   _| | __ _| |_ _  ___  _ __  ___| |
 | |    / _ \| '_ \ / _` | '__/ _` | __| | | | |/ _` | __| |/ _ \| '_ \/ __| |
 | |___| (_) | | | | (_| | | | (_| | |_| |_| | | (_| | |_| | (_) | | | \__ \_|
  \_____\___/|_| |_|\__, |_|  \__,_|\__|\__,_|_|\__,_|\__|_|\___/|_| |_|___(_)
                     __/ |                                                    
                    |___/   
        
        """)

        print(f"""\nYou fought bravely and restored the sacred idol and treasure.""")
        sys.exit(0)

    elif second_input != correct_answer_upper or second_input != correct_answer_lower:

# the player is dead, call game_over() function with the "reason"

        game_over("Oops! Monster killed you")
        print("Thanks for playing!")

# the player won the game

# activate play_again() function
        play_again()
    else:

# call game_over() with "reason"
        game_over("invalid entry. Please try again.")


# defining play_again function
def play_again():
    print(f"""\nDo you want to play again? (Yes or No)""")

# converting the player's input to lower_case
    answer = input(prompt=">").lower()

    if answer in ["yes", "YES", "Yes"]:
        print(f"{answer}")

# if the player typed "yes" or "YES" or "Yes" start the game from the beginning
        start()

    else:
# if user types anything besides "yes" or "YES", "Yes" exit() the program
        print("exiting the game")
        sys.exit(0)


# defining game_over function that accepts an argument called "reason"
def game_over(reason):

# print the "reason" in a new line (\n)
    print("\n" + reason)
    print(f"""Game Over! Thanks for playing.""")
# ask player to play again or not by activating play_again() function
    play_again()

# start the game
intro()
